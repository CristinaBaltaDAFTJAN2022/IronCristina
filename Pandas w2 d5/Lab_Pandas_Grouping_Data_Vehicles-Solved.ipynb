# %% [markdown]
# # Pandas: grouping

# %%
import pandas as pd
import numpy as np

# %%
cars_df = pd.read_csv("data/vehicles.csv")

# %%
cars_df.head()

# %% [markdown]
# How many Car models?

# %%
cars_df.groupby("Model").count()
# Out:
#                    Make  Year  Engine Displacement  Cylinders  Transmission  \
# Model
# 1-Ton Truck 2WD      16    16                   16         16            16
# 100                  12    12                   12         12            12
# 100 Wagon             3     3                    3          3             3
# 100 quattro           9     9                    9          9             9
# 100 quattro Wagon     3     3                    3          3             3
# ...                 ...   ...                  ...        ...           ...
# iQ                    5     5                    5          5             5
# tC                   24    24                   24         24            24
# xA                    6     6                    6          6             6
# xB                   22    22                   22         22            22
# xD                   14    14                   14         14            14
#
# ...

# %%
cars_model = cars_df["Model"].value_counts()

# %%
cars_model
# Out:
# F150 Pickup 2WD      197
# F150 Pickup 4WD      179
# Truck 2WD            173
# Mustang              170
# Jetta                169
#                     ...
# C300 Convertible       1
# C300 Coupe             1
# C300 FFV               1
# C320 4matic Sedan      1
# DJ Po Vehicle 2WD      1
# Name: Model, Length: 3608, dtype: int64

# %% [markdown]
# Group by the data by the Make  using count function

# %%
cars_df.groupby("Make").count()
# Out:
#                              Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General                       4     4                    4          4
# ASC Incorporated                 1     1                    1          1
# Acura                          302   302                  302        302
# Alfa Romeo                      41    41                   41         41
# American Motors Corporation     22    22                   22         22
# ...                            ...   ...                  ...        ...
# Volkswagen                    1047  1047                 1047       1047
# Volvo                          717   717                  717        717
# Wallace Environmental           32    32                   32         32
# Yugo                             8     8                    8          8
# smart                           20    20                   20         20
#
#                              Transmission  Drivetrain  Vehicle Class  \
# Make
# ...

# %% [markdown]
# What brand has the most cars?

# %%
total_brands =cars_df.groupby("Make")['Model'].count().sort_values(ascending=False)
total_brands
# Out:
# Make
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
#                                       ...
# Excalibur Autos                          1
# S and S Coach Company  E.p. Dutton       1
# Environmental Rsch and Devp Corp         1
# E. P. Dutton, Inc.                       1
# Lambda Control Systems                   1
# Name: Model, Length: 127, dtype: int64

# %%
total_brands = cars_df.groupby("Make")['Model'].count().reset_index()
total_brands[total_brands['Model']==total_brands['Model'].max()]
# Out:
#          Make  Model
# 20  Chevrolet   3643

# %%
total_brands = cars_df.groupby("Make")['Model'].count().reset_index() # we find wich brand hat total model max
total_brands['Model']==total_brands['Model'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# Name: Model, Length: 127, dtype: bool

# %%
cars_df[cars_df['Cylinders']==6] # we check the 6-cylinder cars
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...                      ...                  ...   ...                  ...
# 35900  Wallace Environmental          Wetl 300 GE  1991                  2.9
# 35901  Wallace Environmental          Wetl 300 SL  1991                  2.9
# 35902  Wallace Environmental          Wetl 300 SL  1992                  2.9
# 35903  Wallace Environmental          Wetl 300 TE  1991                  2.9
# 35904  Wallace Environmental          Wetl 300 TE  1992                  2.9
#
# ...

# %%
cars_df[cars_df['Cylinders']==6].shape   # 12765 cars with 6 cylinders
# Out:
# (12765, 15)

# %%
#Converting Grams/Mile to Grams/Km
cars_df["CO2 Emission Grams/Mile"] = cars_df["CO2 Emission Grams/Mile"] / 1.60934
cars_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
cars_df.sort_values(by='CO2 Emission Grams/Mile', ascending=False) #
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# ...            ...       ...   ...                  ...        ...
# 7917     Chevrolet      Volt  2017                  1.5        4.0
# 7916     Chevrolet      Volt  2016                  1.5        4.0
# 3070           BMW    i3 REX  2015                  0.6        2.0
# 3069           BMW    i3 REX  2014                  0.6        2.0
# 3071           BMW    i3 REX  2016                  0.6        2.0
#
#                            Transmission         Drivetrain    Vehicle Class  \
# 20897                      Manual 5-spd   Rear-Wheel Drive      Two Seaters
# ...

# %%
cars_df['CO2 Emission Grams/Mile'].value_counts()
# Out:
# 190.628163    3114
# 180.595102    2763
# 171.565347    2697
# 163.395569    2662
# 228.753796    2023
#               ...
# 269.500646       1
# 280.697665       1
# 309.269366       1
# 273.729451       1
# 94.981603        1
# Name: CO2 Emission Grams/Mile, Length: 575, dtype: int64

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand

# %%
cars_df.groupby('Make').mean()
# Out:
#                                     Year  Engine Displacement  Cylinders  \
# Make
# AM General                   1984.500000             3.350000   5.000000
# ASC Incorporated             1987.000000             3.800000   6.000000
# Acura                        2003.493377             2.834768   5.231788
# Alfa Romeo                   1991.878049             2.556098   5.317073
# American Motors Corporation  1984.590909             3.813636   5.545455
# ...                                  ...                  ...        ...
# Volkswagen                   2002.928367             2.236008   4.595033
# Volvo                        2002.182706             2.504742   4.945607
# Wallace Environmental        1991.500000             4.315625   7.812500
# Yugo                         1988.375000             1.200000   4.000000
# smart                        2012.500000             0.980000   3.000000
#
#                              Fuel Barrels/Year   City MPG  Highway MPG  \
# Make
# ...

# %%
cars_emission =cars_df[('CO2 Emission Grams/Mile')/ 1.60934].groupby["Make"].mean().sort_values(ascending=False)
cars_emission
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cj/gbt4rs1d4tx3brkqknks4y5r0000gn/T/ipykernel_8832/1511734331.py in <module>
# ----> 1 cars_emission =cars_df[('CO2 Emission Grams/Mile')/ 1.60934].groupby["Make"].mean().sort_values(ascending=False)
#       2 cars_emission
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
cars_emission = cars_df.groupby("Make")['CO2 Emission Grams/Mile'].mean().reset_index()
cars_emission[cars_emission['CO2 Emission Grams/Mile']==cars_emission['CO2 Emission Grams/Mile'].max()]
# Out:
#        Make  CO2 Emission Grams/Mile
# 119  Vector               405.084847

# %%
cars_emission['CO2 Emission Grams/Mile']==cars_emission['CO2 Emission Grams/Mile']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 122    True
# 123    True
# 124    True
# 125    True
# 126    True
# Name: CO2 Emission Grams/Mile, Length: 127, dtype: bool

# %%
cars_df.groupby(['Make','CO2 Emission Grams/Mile']).mean()
# Out:
#                                             Year  Engine Displacement  \
# Make             CO2 Emission Grams/Mile
# AM General       201.841585               1984.0                  2.5
#                  214.456684               1985.0                  2.5
#                  263.946688               1984.5                  4.2
# ASC Incorporated 214.456684               1987.0                  3.8
# Acura            88.031730                2013.5                  1.5
# ...                                          ...                  ...
# smart            94.981603                2016.0                  0.9
#                  95.314082                2010.0                  1.0
#                  96.912124                2017.0                  0.9
#                  98.456540                2016.0                  0.9
#                  99.614852                2017.0                  0.9
#
#                                           Cylinders  Fuel Barrels/Year  \
# ...

# %%
### your code us here

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand ... sorted

# %%
### your code us here

# %% [markdown]
# Use `pd.cut` or `pd.qcut` to create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars_df['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
pd.cut(cars_df.Year, bins=4, right=True).head()
 ## your code here
# Out:
# 0    (1983.967, 1992.25]
# 1    (1983.967, 1992.25]
# 2    (1983.967, 1992.25]
# 3    (1983.967, 1992.25]
# 4    (1983.967, 1992.25]
# Name: Year, dtype: category
# Categories (4, interval[float64, right]): [(1983.967, 1992.25] < (1992.25, 2000.5] < (2000.5, 2008.75] < (2008.75, 2017.0]]

# %% [markdown]
# ### Did cars consume more gas in the eighties?

# %% [markdown]
# show the average City_Km/Liter by year_range

# %%
 ### your code is here

# %% [markdown]
# Which brands are more environment friendly?

# %%
cars_df.groupby(["Make","CO2 Emission Grams/Mile"]).max() ### your code is here
##cars_df["CO2 Emission Grams/Mile"]
# Out:
#                                                         Model  Year  \
# Make             CO2 Emission Grams/Mile
# AM General       125.418858                 DJ Po Vehicle 2WD  1984
#                  133.257536               Post Office DJ5 2WD  1985
#                  164.009276               Post Office DJ8 2WD  1985
# ASC Incorporated 133.257536                               GNX  1987
# Acura            54.700517                         ILX Hybrid  2014
# ...                                                       ...   ...
# smart            59.018979                       fortwo coupe  2016
#                  59.225572                       fortwo coupe  2012
#                  60.218551                   fortwo cabriolet  2017
#                  61.178210                       fortwo coupe  2016
#                  61.897953                   fortwo cabriolet  2017
#
#                                           Engine Displacement  Cylinders  \
# ...

# %% [markdown]
# Does the drivetrain affect fuel consumption?

# %%
print(cars_df.Transmission.value_counts()) ##frequency of different transmission
# Out:
# Automatic 4-spd                     10585
# Manual 5-spd                         7787
# Automatic (S6)                       2631
# Automatic 3-spd                      2597
# Manual 6-spd                         2423
# Automatic 5-spd                      2171
# Automatic 6-spd                      1432
# Manual 4-spd                         1306
# Automatic (S8)                        960
# Automatic (S5)                        822
# Automatic (variable gear ratios)      675
# Automatic 7-spd                       662
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        229
# Auto(AM7)                             157
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           74
# ...

# %%
print(cars_df.Drivetrain.value_counts()) # frequency of drivetrain
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %%
print(cars_df["Fuel Type"].value_counts()) # frequency of Fuel type
# Out:
# Regular                        23587
# Premium                         9921
# Gasoline or E85                 1195
# Diesel                           911
# Premium or E85                   121
# Midgrade                          74
# CNG                               60
# Premium and Electricity           20
# Gasoline or natural gas           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
cars_df.sort_values(by='Fuel Barrels/Year', ascending=False) # consume moust fuel
# Out:
#               Make              Model  Year  Engine Displacement  Cylinders  \
# 20898  Lamborghini           Countach  1990                  5.2       12.0
# 20896  Lamborghini           Countach  1988                  5.2       12.0
# 20895  Lamborghini           Countach  1987                  5.2       12.0
# 20894  Lamborghini           Countach  1986                  5.2       12.0
# 20897  Lamborghini           Countach  1989                  5.2       12.0
# ...            ...                ...   ...                  ...        ...
# 17296        Honda          Civic CNG  2009                  1.8        4.0
# 17396        Honda  Civic Natural Gas  2013                  1.8        4.0
# 17398        Honda  Civic Natural Gas  2015                  1.8        4.0
# 17397        Honda  Civic Natural Gas  2014                  1.8        4.0
# 17395        Honda  Civic Natural Gas  2012                  1.8        4.0
#
# ...

# %% [markdown]
# Use `groupby` and `aggregate` with different aggregation measures for different columns:

# %% [markdown]
# aggregate with average City_Km/Liter and the count of the Trans

# %%
## your code is here

# %% [markdown]
# aggregate with average City_Km/Liter and the minimum of the Trans

# %%
### your code is here
