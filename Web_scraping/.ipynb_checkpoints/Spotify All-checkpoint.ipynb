# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
# Loading the dataset
spotify = pd.read_csv('spotify_df.csv')

# %%
spotify1 =pd.read_csv('spotify1__df.csv')

# %%
spotify2=pd.read_csv('spotify2__df.csv')

# %%
all_spotify=pd.concat([spotify, spotify1, spotify2], axis=0).reset_index()

# %%
all_spotify
# Out:
#       index  Unnamed: 0  danceability  energy  key  loudness  mode  \
# 0         0           0         0.522  0.8170    0    -6.170     1
# 1         1           1         0.533  0.7760    8    -7.092     1
# 2         2           2         0.692  0.6510    9    -8.267     1
# 3         3           3         0.873  0.6510    1    -4.179     1
# 4         4           4         0.682  0.6050    8   -10.771     1
# ...     ...         ...           ...     ...  ...       ...   ...
# 6361   1273         442         0.628  0.7370    7    -4.437     1
# 6362   1274         443         0.784  0.5390    8    -8.148     0
# 6363   1275         444         0.410  0.0485    0   -13.918     1
# 6364   1276         445         0.854  0.6740   11    -4.896     1
# 6365   1277         446         0.908  0.6690    7    -2.827     1
#
#       speechiness  acousticness  instrumentalness  ...    tempo  \
# 0          0.0512       0.32900          0.000002  ...  151.106
# 1          0.0847       0.15100          0.000087  ...   90.061
# 2          0.0324       0.29200          0.002410  ...   97.923
# 3          0.0374       0.02510          0.000107  ...  115.002
# 4          0.0403       0.18500          0.003260  ...  125.960
# ...           ...           ...               ...  ...      ...
# 6361       0.0410       0.06250          0.000000  ...   91.507
# 6362       0.0628       0.69000          0.000017  ...  133.963
# 6363       0.0380       0.94700          0.000000  ...  137.970
# 6364       0.0705       0.02040          0.000000  ...  125.845
# 6365       0.0738       0.00286          0.000000  ...  112.238
#
#                 type                      id  \
# 0     audio_features  5SfM1f729pv1DdiEcyDiex
# 1     audio_features  7gyDV6Y7GmHqQS4KnzI5Zk
# 2     audio_features  0bRXwKfigvpKZUurwqAlEh
# 3     audio_features  2JHHXGSC6Ra3IJOBNLbhS6
# 4     audio_features  241RmK77gecJ1y7jOoQ5lu
# ...              ...                     ...
# 6361  audio_features  0nhBKubnVz9yFNNprBniWz
# 6362  audio_features  0WOvSEVpUGkNufX0w0M06F
# 6363  audio_features  6yIHGmQLJxWAUZ1ZkENemN
# 6364  audio_features  6A5NlmBCsCGbJ27jHQgKV5
# 6365  audio_features  7lQ8MOhq6IN2w8EYcFNSUk
#
#                                        uri  \
# 0     spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                                    ...
# 6361  spotify:track:0nhBKubnVz9yFNNprBniWz
# 6362  spotify:track:0WOvSEVpUGkNufX0w0M06F
# 6363  spotify:track:6yIHGmQLJxWAUZ1ZkENemN
# 6364  spotify:track:6A5NlmBCsCGbJ27jHQgKV5
# 6365  spotify:track:7lQ8MOhq6IN2w8EYcFNSUk
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 6361  https://api.spotify.com/v1/tracks/0nhBKubnVz9y...
# 6362  https://api.spotify.com/v1/tracks/0WOvSEVpUGkN...
# 6363  https://api.spotify.com/v1/tracks/6yIHGmQLJxWA...
# 6364  https://api.spotify.com/v1/tracks/6A5NlmBCsCGb...
# 6365  https://api.spotify.com/v1/tracks/7lQ8MOhq6IN2...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...      204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...      214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...      254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...      178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...      171360
# ...                                                 ...         ...
# 6361  https://api.spotify.com/v1/audio-analysis/0nhB...      185194
# 6362  https://api.spotify.com/v1/audio-analysis/0WOv...      234818
# 6363  https://api.spotify.com/v1/audio-analysis/6yIH...      173175
# 6364  https://api.spotify.com/v1/audio-analysis/6A5N...      210800
# 6365  https://api.spotify.com/v1/audio-analysis/7lQ8...      290320
#
#      time_signature             artists  \
# 0                 4                Yola
# 1                 4  The War and Treaty
# 2                 4        Bill Withers
# 3                 4         Jon Batiste
# 4                 4        Natalie Cole
# ...             ...                 ...
# 6361              4         Troye Sivan
# 6362              4                LANY
# 6363              4      Haley Reinhart
# 6364              4            Jay Sean
# 6365              4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 6361                                              YOUTH
# 6362                                                 13
# 6363                         Can't Help Falling in Love
# 6364                                    Do You Remember
# 6365                                         Without Me
#
# [6366 rows x 22 columns]

# %%
all_spotify.drop(columns =["Unnamed: 0", "index"], inplace=True)

# %%
all_spotify
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522  0.8170    0    -6.170     1       0.0512       0.32900
# 1            0.533  0.7760    8    -7.092     1       0.0847       0.15100
# 2            0.692  0.6510    9    -8.267     1       0.0324       0.29200
# 3            0.873  0.6510    1    -4.179     1       0.0374       0.02510
# 4            0.682  0.6050    8   -10.771     1       0.0403       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 6361         0.628  0.7370    7    -4.437     1       0.0410       0.06250
# 6362         0.784  0.5390    8    -8.148     0       0.0628       0.69000
# 6363         0.410  0.0485    0   -13.918     1       0.0380       0.94700
# 6364         0.854  0.6740   11    -4.896     1       0.0705       0.02040
# 6365         0.908  0.6690    7    -2.827     1       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000002    0.0807    0.562  151.106  audio_features
# 1             0.000087    0.1300    0.697   90.061  audio_features
# 2             0.002410    0.1050    0.706   97.923  audio_features
# 3             0.000107    0.2130    0.828  115.002  audio_features
# 4             0.003260    0.0469    0.914  125.960  audio_features
# ...                ...       ...      ...      ...             ...
# 6361          0.000000    0.0777    0.592   91.507  audio_features
# 6362          0.000017    0.0367    0.697  133.963  audio_features
# 6363          0.000000    0.1080    0.247  137.970  audio_features
# 6364          0.000000    0.1010    0.818  125.845  audio_features
# 6365          0.000000    0.2370    0.662  112.238  audio_features
#
#                           id                                   uri  \
# 0     5SfM1f729pv1DdiEcyDiex  spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     7gyDV6Y7GmHqQS4KnzI5Zk  spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     0bRXwKfigvpKZUurwqAlEh  spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     2JHHXGSC6Ra3IJOBNLbhS6  spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     241RmK77gecJ1y7jOoQ5lu  spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                      ...                                   ...
# 6361  0nhBKubnVz9yFNNprBniWz  spotify:track:0nhBKubnVz9yFNNprBniWz
# 6362  0WOvSEVpUGkNufX0w0M06F  spotify:track:0WOvSEVpUGkNufX0w0M06F
# 6363  6yIHGmQLJxWAUZ1ZkENemN  spotify:track:6yIHGmQLJxWAUZ1ZkENemN
# 6364  6A5NlmBCsCGbJ27jHQgKV5  spotify:track:6A5NlmBCsCGbJ27jHQgKV5
# 6365  7lQ8MOhq6IN2w8EYcFNSUk  spotify:track:7lQ8MOhq6IN2w8EYcFNSUk
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 6361  https://api.spotify.com/v1/tracks/0nhBKubnVz9y...
# 6362  https://api.spotify.com/v1/tracks/0WOvSEVpUGkN...
# 6363  https://api.spotify.com/v1/tracks/6yIHGmQLJxWA...
# 6364  https://api.spotify.com/v1/tracks/6A5NlmBCsCGb...
# 6365  https://api.spotify.com/v1/tracks/7lQ8MOhq6IN2...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...       204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...       214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...       254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...       178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...       171360
# ...                                                 ...          ...
# 6361  https://api.spotify.com/v1/audio-analysis/0nhB...       185194
# 6362  https://api.spotify.com/v1/audio-analysis/0WOv...       234818
# 6363  https://api.spotify.com/v1/audio-analysis/6yIH...       173175
# 6364  https://api.spotify.com/v1/audio-analysis/6A5N...       210800
# 6365  https://api.spotify.com/v1/audio-analysis/7lQ8...       290320
#
#       time_signature             artists  \
# 0                  4                Yola
# 1                  4  The War and Treaty
# 2                  4        Bill Withers
# 3                  4         Jon Batiste
# 4                  4        Natalie Cole
# ...              ...                 ...
# 6361               4         Troye Sivan
# 6362               4                LANY
# 6363               4      Haley Reinhart
# 6364               4            Jay Sean
# 6365               4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 6361                                              YOUTH
# 6362                                                 13
# 6363                         Can't Help Falling in Love
# 6364                                    Do You Remember
# 6365                                         Without Me
#
# [6366 rows x 20 columns]

# %% [markdown]
# ## Scaling features

# %%
all_spotify.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   6366.000000  6366.000000  6366.000000  6366.000000  6366.000000
# mean       0.651768     0.573263     5.107446    -8.701131     0.612787
# std        0.153639     0.224468     3.617069     5.418922     0.487151
# min        0.000000     0.002120     0.000000   -43.738000     0.000000
# 25%        0.567000     0.428000     2.000000    -9.893250     0.000000
# 50%        0.667000     0.602000     5.000000    -6.945500     1.000000
# 75%        0.757000     0.743000     8.000000    -5.238250     1.000000
# max        0.980000     1.000000    11.000000     0.175000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  6366.000000   6366.000000       6366.000000  6366.000000  6366.000000
# mean      0.096841      0.313643          0.126147     0.170258     0.511326
# std       0.098038      0.310564          0.287195     0.134019     0.231927
# min       0.000000      0.000018          0.000000     0.005350     0.000000
# 25%       0.038400      0.048400          0.000000     0.094525     0.334000
# 50%       0.053600      0.192000          0.000006     0.119000     0.512000
# 75%       0.108000      0.552000          0.004440     0.195000     0.697000
# max       0.916000      0.996000          0.976000     0.986000     0.982000
#
#              tempo   duration_ms  time_signature
# count  6366.000000  6.366000e+03     6366.000000
# mean    119.967034  2.078696e+05        3.934182
# std      28.195027  7.638505e+04        0.335260
# min       0.000000  5.061300e+04        0.000000
# 25%      98.071500  1.648762e+05        4.000000
# 50%     120.006000  1.989335e+05        4.000000
# 75%     139.713000  2.327532e+05        4.000000
# max     216.587000  1.252322e+06        5.000000

# %%
all_spotify_num = all_spotify._get_numeric_data()

# %%
X= all_spotify_num

# %%
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522  0.8170    0    -6.170     1       0.0512       0.32900
# 1            0.533  0.7760    8    -7.092     1       0.0847       0.15100
# 2            0.692  0.6510    9    -8.267     1       0.0324       0.29200
# 3            0.873  0.6510    1    -4.179     1       0.0374       0.02510
# 4            0.682  0.6050    8   -10.771     1       0.0403       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 6361         0.628  0.7370    7    -4.437     1       0.0410       0.06250
# 6362         0.784  0.5390    8    -8.148     0       0.0628       0.69000
# 6363         0.410  0.0485    0   -13.918     1       0.0380       0.94700
# 6364         0.854  0.6740   11    -4.896     1       0.0705       0.02040
# 6365         0.908  0.6690    7    -2.827     1       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000002    0.0807    0.562  151.106       204693
# 1             0.000087    0.1300    0.697   90.061       214187
# 2             0.002410    0.1050    0.706   97.923       254560
# 3             0.000107    0.2130    0.828  115.002       178290
# 4             0.003260    0.0469    0.914  125.960       171360
# ...                ...       ...      ...      ...          ...
# 6361          0.000000    0.0777    0.592   91.507       185194
# 6362          0.000017    0.0367    0.697  133.963       234818
# 6363          0.000000    0.1080    0.247  137.970       173175
# 6364          0.000000    0.1010    0.818  125.845       210800
# 6365          0.000000    0.2370    0.662  112.238       290320
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 6361               4
# 6362               4
# 6363               4
# 6364               4
# 6365               4
#
# [6366 rows x 13 columns]

# %%
X.drop(columns =["key", "mode", "time_signature"], inplace=True)
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522  0.8170    -6.170       0.0512       0.32900
# 1            0.533  0.7760    -7.092       0.0847       0.15100
# 2            0.692  0.6510    -8.267       0.0324       0.29200
# 3            0.873  0.6510    -4.179       0.0374       0.02510
# 4            0.682  0.6050   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 6361         0.628  0.7370    -4.437       0.0410       0.06250
# 6362         0.784  0.5390    -8.148       0.0628       0.69000
# 6363         0.410  0.0485   -13.918       0.0380       0.94700
# 6364         0.854  0.6740    -4.896       0.0705       0.02040
# 6365         0.908  0.6690    -2.827       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000002    0.0807    0.562  151.106       204693
# 1             0.000087    0.1300    0.697   90.061       214187
# 2             0.002410    0.1050    0.706   97.923       254560
# 3             0.000107    0.2130    0.828  115.002       178290
# 4             0.003260    0.0469    0.914  125.960       171360
# ...                ...       ...      ...      ...          ...
# 6361          0.000000    0.0777    0.592   91.507       185194
# 6362          0.000017    0.0367    0.697  133.963       234818
# 6363          0.000000    0.1080    0.247  137.970       173175
# 6364          0.000000    0.1010    0.818  125.845       210800
# 6365          0.000000    0.2370    0.662  112.238       290320
#
# [6366 rows x 10 columns]

# %% [markdown]
# The scale of "tempo" and "duration_ms" is much bigger than the scale of many other variable!
#
# K-Means is a distance based algorithm: we need to scale / normalize!:

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.522   0.817    -6.170       0.0512        0.3290
# 1         0.533   0.776    -7.092       0.0847        0.1510
# 2         0.692   0.651    -8.267       0.0324        0.2920
# 3         0.873   0.651    -4.179       0.0374        0.0251
# 4         0.682   0.605   -10.771       0.0403        0.1850
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000002    0.0807    0.562  151.106       204693
# 1          0.000087    0.1300    0.697   90.061       214187
# 2          0.002410    0.1050    0.706   97.923       254560
# 3          0.000107    0.2130    0.828  115.002       178290
# 4          0.003260    0.0469    0.914  125.960       171360
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.844693  1.085926  0.467128    -0.465574      0.049453
# 1     -0.773091  0.903258  0.296970    -0.123844     -0.523743
# 2      0.261882  0.346343  0.080120    -0.657350     -0.069694
# 3      1.440059  0.346343  0.834573    -0.606346     -0.929166
# 4      0.196790  0.141398 -0.382001    -0.576763     -0.414256
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.439265 -0.668302  0.218509  1.104500    -0.041589
# 1         -0.438970 -0.300416  0.800635 -1.060768     0.082712
# 2         -0.430879 -0.486971  0.839443 -0.781903     0.611299
# 3         -0.438898  0.318947  1.365513 -0.176110    -0.387273
# 4         -0.427919 -0.920525  1.736348  0.212571    -0.478005

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  6.366000e+03  6.366000e+03  6.366000e+03  6.366000e+03  6.366000e+03
# mean   2.148594e-16  5.463916e-17  1.581100e-16  9.527845e-17  1.798052e-16
# std    1.000079e+00  1.000079e+00  1.000079e+00  1.000079e+00  1.000079e+00
# min   -4.242530e+00 -2.544625e+00 -6.466161e+00 -9.878590e-01 -1.009934e+00
# 25%   -5.517760e-01 -6.471933e-01 -2.200091e-01 -5.961451e-01 -8.541354e-01
# 50%    9.915056e-02  1.280324e-01  3.240071e-01 -4.410917e-01 -3.917143e-01
# 75%    6.849845e-01  7.562326e-01  6.390853e-01  1.138363e-01  7.675585e-01
# max    2.136551e+00  1.901250e+00  1.638117e+00  8.356150e+00  2.197328e+00
#
#        instrumentalness      liveness       valence         tempo  \
# count      6.366000e+03  6.366000e+03  6.366000e+03  6.366000e+03
# mean      -3.253777e-15 -1.073774e-16 -3.607266e-16 -3.644674e-16
# std        1.000079e+00  1.000079e+00  1.000079e+00  1.000079e+00
# min       -4.392708e-01 -1.230579e+00 -2.204860e+00 -4.255235e+00
# 25%       -4.392708e-01 -5.651373e-01 -7.646372e-01 -7.766353e-01
# 50%       -4.392502e-01 -3.824999e-01  2.906599e-03  1.382128e-03
# 75%       -4.238097e-01  1.846273e-01  8.006348e-01  7.003901e-01
# max        2.959382e+00  6.087227e+00  2.029567e+00  3.427113e+00
#
#         duration_ms
# count  6.366000e+03
# mean  -2.058953e-16
# std    1.000079e+00
# min   -2.058896e+00
# 25%   -5.628940e-01
# 50%   -1.169963e-01
# 75%    3.257920e-01
# max    1.367459e+01

# %% [markdown]
# Now, all features will have the same weight.

# %% [markdown]
# ## Clustering the music with K-Means

# %%
kmeans = KMeans(n_clusters=9, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=9, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([0, 7, 7, ..., 4, 7, 7], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 2])
    # show the plot
pyplot.show()

# %%
# Now we have our "model", let's get the clusters and how many observations has each cluster.

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     654
# 1    1339
# 2     688
# 3     624
# 4     524
# 5     708
# 6     185
# 7    1327
# 8     317
# dtype: int64

# %% [markdown]
# Now let's see to which group was assigned every song.

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522  0.8170    -6.170       0.0512       0.32900
# 1            0.533  0.7760    -7.092       0.0847       0.15100
# 2            0.692  0.6510    -8.267       0.0324       0.29200
# 3            0.873  0.6510    -4.179       0.0374       0.02510
# 4            0.682  0.6050   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 6361         0.628  0.7370    -4.437       0.0410       0.06250
# 6362         0.784  0.5390    -8.148       0.0628       0.69000
# 6363         0.410  0.0485   -13.918       0.0380       0.94700
# 6364         0.854  0.6740    -4.896       0.0705       0.02040
# 6365         0.908  0.6690    -2.827       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0             0.000002    0.0807    0.562  151.106       204693        0
# 1             0.000087    0.1300    0.697   90.061       214187        7
# 2             0.002410    0.1050    0.706   97.923       254560        7
# 3             0.000107    0.2130    0.828  115.002       178290        7
# 4             0.003260    0.0469    0.914  125.960       171360        7
# ...                ...       ...      ...      ...          ...      ...
# 6361          0.000000    0.0777    0.592   91.507       185194        7
# 6362          0.000017    0.0367    0.697  133.963       234818        3
# 6363          0.000000    0.1080    0.247  137.970       173175        4
# 6364          0.000000    0.1010    0.818  125.845       210800        7
# 6365          0.000000    0.2370    0.662  112.238       290320        7
#
# [6366 rows x 11 columns]

# %%
cluster_id=pd.concat([X, all_spotify], axis=1)
cluster_id
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522  0.8170    -6.170       0.0512       0.32900
# 1            0.533  0.7760    -7.092       0.0847       0.15100
# 2            0.692  0.6510    -8.267       0.0324       0.29200
# 3            0.873  0.6510    -4.179       0.0374       0.02510
# 4            0.682  0.6050   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 6361         0.628  0.7370    -4.437       0.0410       0.06250
# 6362         0.784  0.5390    -8.148       0.0628       0.69000
# 6363         0.410  0.0485   -13.918       0.0380       0.94700
# 6364         0.854  0.6740    -4.896       0.0705       0.02040
# 6365         0.908  0.6690    -2.827       0.0738       0.00286
#
#       instrumentalness  liveness  valence    tempo  duration_ms  ...    tempo  \
# 0             0.000002    0.0807    0.562  151.106       204693  ...  151.106
# 1             0.000087    0.1300    0.697   90.061       214187  ...   90.061
# 2             0.002410    0.1050    0.706   97.923       254560  ...   97.923
# 3             0.000107    0.2130    0.828  115.002       178290  ...  115.002
# 4             0.003260    0.0469    0.914  125.960       171360  ...  125.960
# ...                ...       ...      ...      ...          ...  ...      ...
# 6361          0.000000    0.0777    0.592   91.507       185194  ...   91.507
# 6362          0.000017    0.0367    0.697  133.963       234818  ...  133.963
# 6363          0.000000    0.1080    0.247  137.970       173175  ...  137.970
# 6364          0.000000    0.1010    0.818  125.845       210800  ...  125.845
# 6365          0.000000    0.2370    0.662  112.238       290320  ...  112.238
#
#                 type                      id  \
# 0     audio_features  5SfM1f729pv1DdiEcyDiex
# 1     audio_features  7gyDV6Y7GmHqQS4KnzI5Zk
# 2     audio_features  0bRXwKfigvpKZUurwqAlEh
# 3     audio_features  2JHHXGSC6Ra3IJOBNLbhS6
# 4     audio_features  241RmK77gecJ1y7jOoQ5lu
# ...              ...                     ...
# 6361  audio_features  0nhBKubnVz9yFNNprBniWz
# 6362  audio_features  0WOvSEVpUGkNufX0w0M06F
# 6363  audio_features  6yIHGmQLJxWAUZ1ZkENemN
# 6364  audio_features  6A5NlmBCsCGbJ27jHQgKV5
# 6365  audio_features  7lQ8MOhq6IN2w8EYcFNSUk
#
#                                        uri  \
# 0     spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                                    ...
# 6361  spotify:track:0nhBKubnVz9yFNNprBniWz
# 6362  spotify:track:0WOvSEVpUGkNufX0w0M06F
# 6363  spotify:track:6yIHGmQLJxWAUZ1ZkENemN
# 6364  spotify:track:6A5NlmBCsCGbJ27jHQgKV5
# 6365  spotify:track:7lQ8MOhq6IN2w8EYcFNSUk
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 6361  https://api.spotify.com/v1/tracks/0nhBKubnVz9y...
# 6362  https://api.spotify.com/v1/tracks/0WOvSEVpUGkN...
# 6363  https://api.spotify.com/v1/tracks/6yIHGmQLJxWA...
# 6364  https://api.spotify.com/v1/tracks/6A5NlmBCsCGb...
# 6365  https://api.spotify.com/v1/tracks/7lQ8MOhq6IN2...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...       204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...       214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...       254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...       178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...       171360
# ...                                                 ...          ...
# 6361  https://api.spotify.com/v1/audio-analysis/0nhB...       185194
# 6362  https://api.spotify.com/v1/audio-analysis/0WOv...       234818
# 6363  https://api.spotify.com/v1/audio-analysis/6yIH...       173175
# 6364  https://api.spotify.com/v1/audio-analysis/6A5N...       210800
# 6365  https://api.spotify.com/v1/audio-analysis/7lQ8...       290320
#
#       time_signature             artists  \
# 0                  4                Yola
# 1                  4  The War and Treaty
# 2                  4        Bill Withers
# 3                  4         Jon Batiste
# 4                  4        Natalie Cole
# ...              ...                 ...
# 6361               4         Troye Sivan
# 6362               4                LANY
# 6363               4      Haley Reinhart
# 6364               4            Jay Sean
# 6365               4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 6361                                              YOUTH
# 6362                                                 13
# 6363                         Can't Help Falling in Love
# 6364                                    Do You Remember
# 6365                                         Without Me
#
# [6366 rows x 31 columns]

# %%
cluster_id.to_csv(r'cluster_id.csv')

# %%
X[X['cluster'] == 2].sample()
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 4039         0.567   0.227   -18.948       0.0337         0.518
#
#       instrumentalness  liveness  valence   tempo  duration_ms  cluster
# 4039             0.688    0.0891    0.566  89.871       194024        2

# %% [markdown]
# ## Playing with the parameters

# %%
kmeans.inertia_
# Out:
# 27404.621383084785

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    #filename = "Model/kmeans_" + str(k) + ".pickle"
    #with open(filename, "wb") as f:
        #pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
kmeans = KMeans(n_clusters=9,
                    random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=9, random_state=1234)

# %%
with open("scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

with open("kmeans_9.pickle", "wb") as f:
    pickle.dump(kmeans,f)

# %%
#all_spotify_df.to_csv(r'all_spotify__df.csv')
