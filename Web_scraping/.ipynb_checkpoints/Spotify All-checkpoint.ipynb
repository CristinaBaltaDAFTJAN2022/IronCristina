# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
# Loading the dataset
spotify = pd.read_csv('spotify_df.csv')

# %%
spotify1 =pd.read_csv('spotify1__df.csv')

# %%
spotify2=pd.read_csv('spotify2__df.csv')

# %%
spotify3=pd.read_csv('spotify3__df.csv')

# %%
all_spotify=pd.concat([spotify, spotify1, spotify2, spotify3], axis=0).reset_index()

# %%
all_spotify
# Out:
#       index  Unnamed: 0  danceability  energy  key  loudness  mode  \
# 0         0           0         0.522   0.817    0    -6.170     1
# 1         1           1         0.533   0.776    8    -7.092     1
# 2         2           2         0.692   0.651    9    -8.267     1
# 3         3           3         0.873   0.651    1    -4.179     1
# 4         4           4         0.682   0.605    8   -10.771     1
# ...     ...         ...           ...     ...  ...       ...   ...
# 9861   3495         763         0.585   0.776    5    -5.898     1
# 9862   3496         764         0.377   0.681    7    -8.039     1
# 9863   3497         765         0.601   0.794    7    -5.844     0
# 9864   3498         766         0.588   0.670    0    -6.439     1
# 9865   3499         767         0.780   0.768    6    -4.325     0
#
#       speechiness  acousticness  instrumentalness  ...    tempo  \
# 0          0.0512       0.32900          0.000002  ...  151.106
# 1          0.0847       0.15100          0.000087  ...   90.061
# 2          0.0324       0.29200          0.002410  ...   97.923
# 3          0.0374       0.02510          0.000107  ...  115.002
# 4          0.0403       0.18500          0.003260  ...  125.960
# ...           ...           ...               ...  ...      ...
# 9861       0.0459       0.05720          0.000008  ...   77.987
# 9862       0.0298       0.00088          0.002300  ...  108.789
# 9863       0.0671       0.00987          0.000001  ...  114.066
# 9864       0.0473       0.01040          0.000003  ...  118.159
# 9865       0.2380       0.03710          0.000002  ...   80.063
#
#                 type                      id  \
# 0     audio_features  5SfM1f729pv1DdiEcyDiex
# 1     audio_features  7gyDV6Y7GmHqQS4KnzI5Zk
# 2     audio_features  0bRXwKfigvpKZUurwqAlEh
# 3     audio_features  2JHHXGSC6Ra3IJOBNLbhS6
# 4     audio_features  241RmK77gecJ1y7jOoQ5lu
# ...              ...                     ...
# 9861  audio_features  5xEM5hIgJ1jjgcEBfpkt2F
# 9862  audio_features  1QEEqeFIZktqIpPI4jSVSF
# 9863  audio_features  02dRkCEc8Q5ch4TTcnLxOn
# 9864  audio_features  5N4erncE7kuUccm7zEmwzk
# 9865  audio_features  3UmaczJpikHgJFyBTAJVoz
#
#                                        uri  \
# 0     spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                                    ...
# 9861  spotify:track:5xEM5hIgJ1jjgcEBfpkt2F
# 9862  spotify:track:1QEEqeFIZktqIpPI4jSVSF
# 9863  spotify:track:02dRkCEc8Q5ch4TTcnLxOn
# 9864  spotify:track:5N4erncE7kuUccm7zEmwzk
# 9865  spotify:track:3UmaczJpikHgJFyBTAJVoz
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 9861  https://api.spotify.com/v1/tracks/5xEM5hIgJ1jj...
# 9862  https://api.spotify.com/v1/tracks/1QEEqeFIZktq...
# 9863  https://api.spotify.com/v1/tracks/02dRkCEc8Q5c...
# 9864  https://api.spotify.com/v1/tracks/5N4erncE7kuU...
# 9865  https://api.spotify.com/v1/tracks/3UmaczJpikHg...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...      204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...      214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...      254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...      178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...      171360
# ...                                                 ...         ...
# 9861  https://api.spotify.com/v1/audio-analysis/5xEM...      244507
# 9862  https://api.spotify.com/v1/audio-analysis/1QEE...      285133
# 9863  https://api.spotify.com/v1/audio-analysis/02dR...      217099
# 9864  https://api.spotify.com/v1/audio-analysis/5N4e...      238173
# 9865  https://api.spotify.com/v1/audio-analysis/3Uma...      404107
#
#      time_signature             artists  \
# 0                 4                Yola
# 1                 4  The War and Treaty
# 2                 4        Bill Withers
# 3                 4         Jon Batiste
# 4                 4        Natalie Cole
# ...             ...                 ...
# 9861              4       Avril Lavigne
# 9862              4              Boston
# 9863              4         Mark Ronson
# 9864              4           Silk City
# 9865              4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 9861                                        Complicated
# 9862                                More Than a Feeling
# 9863    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 9864                        Electricity (with Dua Lipa)
# 9865                                               Stan
#
# [9866 rows x 22 columns]

# %%
all_spotify.drop(columns =["Unnamed: 0", "index"], inplace=True)

# %%
all_spotify
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522   0.817    0    -6.170     1       0.0512       0.32900
# 1            0.533   0.776    8    -7.092     1       0.0847       0.15100
# 2            0.692   0.651    9    -8.267     1       0.0324       0.29200
# 3            0.873   0.651    1    -4.179     1       0.0374       0.02510
# 4            0.682   0.605    8   -10.771     1       0.0403       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 9861         0.585   0.776    5    -5.898     1       0.0459       0.05720
# 9862         0.377   0.681    7    -8.039     1       0.0298       0.00088
# 9863         0.601   0.794    7    -5.844     0       0.0671       0.00987
# 9864         0.588   0.670    0    -6.439     1       0.0473       0.01040
# 9865         0.780   0.768    6    -4.325     0       0.2380       0.03710
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000002    0.0807    0.562  151.106  audio_features
# 1             0.000087    0.1300    0.697   90.061  audio_features
# 2             0.002410    0.1050    0.706   97.923  audio_features
# 3             0.000107    0.2130    0.828  115.002  audio_features
# 4             0.003260    0.0469    0.914  125.960  audio_features
# ...                ...       ...      ...      ...             ...
# 9861          0.000008    0.3000    0.427   77.987  audio_features
# 9862          0.002300    0.0504    0.285  108.789  audio_features
# 9863          0.000001    0.4180    0.244  114.066  audio_features
# 9864          0.000003    0.3380    0.505  118.159  audio_features
# 9865          0.000002    0.5180    0.507   80.063  audio_features
#
#                           id                                   uri  \
# 0     5SfM1f729pv1DdiEcyDiex  spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     7gyDV6Y7GmHqQS4KnzI5Zk  spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     0bRXwKfigvpKZUurwqAlEh  spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     2JHHXGSC6Ra3IJOBNLbhS6  spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     241RmK77gecJ1y7jOoQ5lu  spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                      ...                                   ...
# 9861  5xEM5hIgJ1jjgcEBfpkt2F  spotify:track:5xEM5hIgJ1jjgcEBfpkt2F
# 9862  1QEEqeFIZktqIpPI4jSVSF  spotify:track:1QEEqeFIZktqIpPI4jSVSF
# 9863  02dRkCEc8Q5ch4TTcnLxOn  spotify:track:02dRkCEc8Q5ch4TTcnLxOn
# 9864  5N4erncE7kuUccm7zEmwzk  spotify:track:5N4erncE7kuUccm7zEmwzk
# 9865  3UmaczJpikHgJFyBTAJVoz  spotify:track:3UmaczJpikHgJFyBTAJVoz
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 9861  https://api.spotify.com/v1/tracks/5xEM5hIgJ1jj...
# 9862  https://api.spotify.com/v1/tracks/1QEEqeFIZktq...
# 9863  https://api.spotify.com/v1/tracks/02dRkCEc8Q5c...
# 9864  https://api.spotify.com/v1/tracks/5N4erncE7kuU...
# 9865  https://api.spotify.com/v1/tracks/3UmaczJpikHg...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...       204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...       214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...       254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...       178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...       171360
# ...                                                 ...          ...
# 9861  https://api.spotify.com/v1/audio-analysis/5xEM...       244507
# 9862  https://api.spotify.com/v1/audio-analysis/1QEE...       285133
# 9863  https://api.spotify.com/v1/audio-analysis/02dR...       217099
# 9864  https://api.spotify.com/v1/audio-analysis/5N4e...       238173
# 9865  https://api.spotify.com/v1/audio-analysis/3Uma...       404107
#
#       time_signature             artists  \
# 0                  4                Yola
# 1                  4  The War and Treaty
# 2                  4        Bill Withers
# 3                  4         Jon Batiste
# 4                  4        Natalie Cole
# ...              ...                 ...
# 9861               4       Avril Lavigne
# 9862               4              Boston
# 9863               4         Mark Ronson
# 9864               4           Silk City
# 9865               4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 9861                                        Complicated
# 9862                                More Than a Feeling
# 9863    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 9864                        Electricity (with Dua Lipa)
# 9865                                               Stan
#
# [9866 rows x 20 columns]

# %% [markdown]
# ## Scaling features

# %%
all_spotify.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   9866.000000  9866.000000  9866.000000  9866.000000  9866.000000
# mean       0.636374     0.618383     5.162579    -8.077866     0.615042
# std        0.155502     0.218096     3.623979     4.754274     0.486610
# min        0.000000     0.002120     0.000000   -43.738000     0.000000
# 25%        0.543000     0.483000     2.000000    -9.264250     0.000000
# 50%        0.653000     0.651000     5.000000    -6.710000     1.000000
# 75%        0.746000     0.787000     8.000000    -5.115000     1.000000
# max        0.984000     1.000000    11.000000     1.342000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  9866.000000   9866.000000       9866.000000  9866.000000  9866.000000
# mean      0.096023      0.264028          0.094226     0.173079     0.520619
# std       0.099891      0.288072          0.248253     0.136665     0.233391
# min       0.000000      0.000003          0.000000     0.005350     0.000000
# 25%       0.037300      0.031600          0.000000     0.093425     0.344000
# 50%       0.052400      0.144000          0.000006     0.120000     0.520000
# 75%       0.103000      0.417750          0.002288     0.204000     0.708000
# max       0.916000      0.996000          0.976000     0.988000     0.985000
#
#              tempo   duration_ms  time_signature
# count  9866.000000  9.866000e+03     9866.000000
# mean    120.329253  2.153877e+05        3.951247
# std      27.769890  7.173426e+04        0.309267
# min       0.000000  5.061300e+04        0.000000
# 25%      99.013000  1.739482e+05        4.000000
# 50%     119.987000  2.064650e+05        4.000000
# 75%     138.407000  2.414315e+05        4.000000
# max     216.587000  1.252322e+06        5.000000

# %%
all_spotify_num = all_spotify._get_numeric_data()

# %%
X= all_spotify_num

# %%
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522   0.817    0    -6.170     1       0.0512       0.32900
# 1            0.533   0.776    8    -7.092     1       0.0847       0.15100
# 2            0.692   0.651    9    -8.267     1       0.0324       0.29200
# 3            0.873   0.651    1    -4.179     1       0.0374       0.02510
# 4            0.682   0.605    8   -10.771     1       0.0403       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 9861         0.585   0.776    5    -5.898     1       0.0459       0.05720
# 9862         0.377   0.681    7    -8.039     1       0.0298       0.00088
# 9863         0.601   0.794    7    -5.844     0       0.0671       0.00987
# 9864         0.588   0.670    0    -6.439     1       0.0473       0.01040
# 9865         0.780   0.768    6    -4.325     0       0.2380       0.03710
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000002    0.0807    0.562  151.106       204693
# 1             0.000087    0.1300    0.697   90.061       214187
# 2             0.002410    0.1050    0.706   97.923       254560
# 3             0.000107    0.2130    0.828  115.002       178290
# 4             0.003260    0.0469    0.914  125.960       171360
# ...                ...       ...      ...      ...          ...
# 9861          0.000008    0.3000    0.427   77.987       244507
# 9862          0.002300    0.0504    0.285  108.789       285133
# 9863          0.000001    0.4180    0.244  114.066       217099
# 9864          0.000003    0.3380    0.505  118.159       238173
# 9865          0.000002    0.5180    0.507   80.063       404107
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9861               4
# 9862               4
# 9863               4
# 9864               4
# 9865               4
#
# [9866 rows x 13 columns]

# %%
X.drop(columns =["key", "mode", "time_signature"], inplace=True)
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522   0.817    -6.170       0.0512       0.32900
# 1            0.533   0.776    -7.092       0.0847       0.15100
# 2            0.692   0.651    -8.267       0.0324       0.29200
# 3            0.873   0.651    -4.179       0.0374       0.02510
# 4            0.682   0.605   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 9861         0.585   0.776    -5.898       0.0459       0.05720
# 9862         0.377   0.681    -8.039       0.0298       0.00088
# 9863         0.601   0.794    -5.844       0.0671       0.00987
# 9864         0.588   0.670    -6.439       0.0473       0.01040
# 9865         0.780   0.768    -4.325       0.2380       0.03710
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.000002    0.0807    0.562  151.106       204693
# 1             0.000087    0.1300    0.697   90.061       214187
# 2             0.002410    0.1050    0.706   97.923       254560
# 3             0.000107    0.2130    0.828  115.002       178290
# 4             0.003260    0.0469    0.914  125.960       171360
# ...                ...       ...      ...      ...          ...
# 9861          0.000008    0.3000    0.427   77.987       244507
# 9862          0.002300    0.0504    0.285  108.789       285133
# 9863          0.000001    0.4180    0.244  114.066       217099
# 9864          0.000003    0.3380    0.505  118.159       238173
# 9865          0.000002    0.5180    0.507   80.063       404107
#
# [9866 rows x 10 columns]

# %% [markdown]
# The scale of "tempo" and "duration_ms" is much bigger than the scale of many other variable!
#
# K-Means is a distance based algorithm: we need to scale / normalize!:

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.522   0.817    -6.170       0.0512        0.3290
# 1         0.533   0.776    -7.092       0.0847        0.1510
# 2         0.692   0.651    -8.267       0.0324        0.2920
# 3         0.873   0.651    -4.179       0.0374        0.0251
# 4         0.682   0.605   -10.771       0.0403        0.1850
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000002    0.0807    0.562  151.106       204693
# 1          0.000087    0.1300    0.697   90.061       214187
# 2          0.002410    0.1050    0.706   97.923       254560
# 3          0.000107    0.2130    0.828  115.002       178290
# 4          0.003260    0.0469    0.914  125.960       171360
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.735548  0.910733  0.401315    -0.448736      0.225551
# 1     -0.664806  0.722733  0.207375    -0.113355     -0.392381
# 2      0.357737  0.149560 -0.039784    -0.636950      0.097104
# 3      1.521765  0.149560  0.820118    -0.586893     -0.829447
# 4      0.293426 -0.061367 -0.566494    -0.557860     -0.274349
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.379572 -0.675984  0.177313  1.108334    -0.149095
# 1         -0.379230 -0.315229  0.755771 -1.090022    -0.016738
# 2         -0.369870 -0.498168  0.794335 -0.806895     0.546104
# 3         -0.379147  0.292126  1.317091 -0.191845    -0.517180
# 4         -0.366446 -0.923317  1.685590  0.202775    -0.613792

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  9.866000e+03  9.866000e+03  9.866000e+03  9.866000e+03  9.866000e+03
# mean   7.655768e-16 -4.902829e-16  1.683227e-16  3.388510e-16 -3.610082e-16
# std    1.000051e+00  1.000051e+00  1.000051e+00  1.000051e+00  1.000051e+00
# min   -4.092578e+00 -2.825800e+00 -7.501027e+00 -9.613189e-01 -9.165718e-01
# 25%   -6.004954e-01 -6.207833e-01 -2.495531e-01 -5.878943e-01 -8.068818e-01
# 50%    1.069248e-01  1.495604e-01  2.877276e-01 -4.367223e-01 -4.166820e-01
# 75%    7.050163e-01  7.731719e-01  6.232322e-01  6.985371e-02  5.336488e-01
# max    2.235616e+00  1.749858e+00  1.981447e+00  8.209109e+00  2.541060e+00
#
#        instrumentalness      liveness       valence         tempo  \
# count      9.866000e+03  9.866000e+03  9.866000e+03  9.866000e+03
# mean      -2.761351e-15 -6.319696e-17 -9.953578e-17 -9.078037e-16
# std        1.000051e+00  1.000051e+00  1.000051e+00  1.000051e+00
# min       -3.795780e-01 -1.227361e+00 -2.230790e+00 -4.333303e+00
# 25%       -3.795780e-01 -5.828684e-01 -7.567911e-01 -7.676420e-01
# 50%       -3.795525e-01 -3.884047e-01 -2.652360e-03 -1.232522e-02
# 75%       -3.703631e-01  2.262686e-01  8.029050e-01  6.510167e-01
# max        3.552098e+00  5.963220e+00  1.989817e+00  3.466439e+00
#
#         duration_ms
# count  9.866000e+03
# mean  -2.123670e-16
# std    1.000051e+00
# min   -2.297131e+00
# 25%   -5.777087e-01
# 50%   -1.243911e-01
# 75%    3.630785e-01
# max    1.445595e+01

# %% [markdown]
# Now, all features will have the same weight.

# %% [markdown]
# ## Clustering the music with K-Means

# %%
kmeans = KMeans(n_clusters=9, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=9, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([3, 4, 4, ..., 5, 0, 5], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 2])
    # show the plot
pyplot.show()

# %%
# Now we have our "model", let's get the clusters and how many observations has each cluster.

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    1210
# 1    1716
# 2    1085
# 3    1036
# 4    2328
# 5     542
# 6     194
# 7     713
# 8    1042
# dtype: int64

# %% [markdown]
# Now let's see to which group was assigned every song.

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522   0.817    -6.170       0.0512       0.32900
# 1            0.533   0.776    -7.092       0.0847       0.15100
# 2            0.692   0.651    -8.267       0.0324       0.29200
# 3            0.873   0.651    -4.179       0.0374       0.02510
# 4            0.682   0.605   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 9861         0.585   0.776    -5.898       0.0459       0.05720
# 9862         0.377   0.681    -8.039       0.0298       0.00088
# 9863         0.601   0.794    -5.844       0.0671       0.00987
# 9864         0.588   0.670    -6.439       0.0473       0.01040
# 9865         0.780   0.768    -4.325       0.2380       0.03710
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0             0.000002    0.0807    0.562  151.106       204693        3
# 1             0.000087    0.1300    0.697   90.061       214187        4
# 2             0.002410    0.1050    0.706   97.923       254560        4
# 3             0.000107    0.2130    0.828  115.002       178290        4
# 4             0.003260    0.0469    0.914  125.960       171360        4
# ...                ...       ...      ...      ...          ...      ...
# 9861          0.000008    0.3000    0.427   77.987       244507        0
# 9862          0.002300    0.0504    0.285  108.789       285133        0
# 9863          0.000001    0.4180    0.244  114.066       217099        5
# 9864          0.000003    0.3380    0.505  118.159       238173        0
# 9865          0.000002    0.5180    0.507   80.063       404107        5
#
# [9866 rows x 11 columns]

# %%
cluster_id=pd.concat([X, all_spotify], axis=1)
cluster_id
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.522   0.817    -6.170       0.0512       0.32900
# 1            0.533   0.776    -7.092       0.0847       0.15100
# 2            0.692   0.651    -8.267       0.0324       0.29200
# 3            0.873   0.651    -4.179       0.0374       0.02510
# 4            0.682   0.605   -10.771       0.0403       0.18500
# ...            ...     ...       ...          ...           ...
# 9861         0.585   0.776    -5.898       0.0459       0.05720
# 9862         0.377   0.681    -8.039       0.0298       0.00088
# 9863         0.601   0.794    -5.844       0.0671       0.00987
# 9864         0.588   0.670    -6.439       0.0473       0.01040
# 9865         0.780   0.768    -4.325       0.2380       0.03710
#
#       instrumentalness  liveness  valence    tempo  duration_ms  ...    tempo  \
# 0             0.000002    0.0807    0.562  151.106       204693  ...  151.106
# 1             0.000087    0.1300    0.697   90.061       214187  ...   90.061
# 2             0.002410    0.1050    0.706   97.923       254560  ...   97.923
# 3             0.000107    0.2130    0.828  115.002       178290  ...  115.002
# 4             0.003260    0.0469    0.914  125.960       171360  ...  125.960
# ...                ...       ...      ...      ...          ...  ...      ...
# 9861          0.000008    0.3000    0.427   77.987       244507  ...   77.987
# 9862          0.002300    0.0504    0.285  108.789       285133  ...  108.789
# 9863          0.000001    0.4180    0.244  114.066       217099  ...  114.066
# 9864          0.000003    0.3380    0.505  118.159       238173  ...  118.159
# 9865          0.000002    0.5180    0.507   80.063       404107  ...   80.063
#
#                 type                      id  \
# 0     audio_features  5SfM1f729pv1DdiEcyDiex
# 1     audio_features  7gyDV6Y7GmHqQS4KnzI5Zk
# 2     audio_features  0bRXwKfigvpKZUurwqAlEh
# 3     audio_features  2JHHXGSC6Ra3IJOBNLbhS6
# 4     audio_features  241RmK77gecJ1y7jOoQ5lu
# ...              ...                     ...
# 9861  audio_features  5xEM5hIgJ1jjgcEBfpkt2F
# 9862  audio_features  1QEEqeFIZktqIpPI4jSVSF
# 9863  audio_features  02dRkCEc8Q5ch4TTcnLxOn
# 9864  audio_features  5N4erncE7kuUccm7zEmwzk
# 9865  audio_features  3UmaczJpikHgJFyBTAJVoz
#
#                                        uri  \
# 0     spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                                    ...
# 9861  spotify:track:5xEM5hIgJ1jjgcEBfpkt2F
# 9862  spotify:track:1QEEqeFIZktqIpPI4jSVSF
# 9863  spotify:track:02dRkCEc8Q5ch4TTcnLxOn
# 9864  spotify:track:5N4erncE7kuUccm7zEmwzk
# 9865  spotify:track:3UmaczJpikHgJFyBTAJVoz
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 9861  https://api.spotify.com/v1/tracks/5xEM5hIgJ1jj...
# 9862  https://api.spotify.com/v1/tracks/1QEEqeFIZktq...
# 9863  https://api.spotify.com/v1/tracks/02dRkCEc8Q5c...
# 9864  https://api.spotify.com/v1/tracks/5N4erncE7kuU...
# 9865  https://api.spotify.com/v1/tracks/3UmaczJpikHg...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...       204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...       214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...       254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...       178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...       171360
# ...                                                 ...          ...
# 9861  https://api.spotify.com/v1/audio-analysis/5xEM...       244507
# 9862  https://api.spotify.com/v1/audio-analysis/1QEE...       285133
# 9863  https://api.spotify.com/v1/audio-analysis/02dR...       217099
# 9864  https://api.spotify.com/v1/audio-analysis/5N4e...       238173
# 9865  https://api.spotify.com/v1/audio-analysis/3Uma...       404107
#
#       time_signature             artists  \
# 0                  4                Yola
# 1                  4  The War and Treaty
# 2                  4        Bill Withers
# 3                  4         Jon Batiste
# 4                  4        Natalie Cole
# ...              ...                 ...
# 9861               4       Avril Lavigne
# 9862               4              Boston
# 9863               4         Mark Ronson
# 9864               4           Silk City
# 9865               4              Eminem
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 9861                                        Complicated
# 9862                                More Than a Feeling
# 9863    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 9864                        Electricity (with Dua Lipa)
# 9865                                               Stan
#
# [9866 rows x 31 columns]

# %%
cluster_id.to_csv(r'cluster_id.csv')

# %%
X[X['cluster'] == 2].sample()
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 1289         0.608   0.305   -14.037        0.053         0.653
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 1289               0.0     0.103    0.222  113.818       206975        2

# %% [markdown]
# ## Playing with the parameters

# %%
kmeans.inertia_
# Out:
# 44588.709347284246

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    #filename = "Model/kmeans_" + str(k) + ".pickle"
    #with open(filename, "wb") as f:
        #pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
kmeans = KMeans(n_clusters=9,
                    random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=9, random_state=1234)

# %%
with open("scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

with open("kmeans_9.pickle", "wb") as f:
    pickle.dump(kmeans,f)

# %%
#all_spotify_df.to_csv(r'all_spotify__df.csv')
