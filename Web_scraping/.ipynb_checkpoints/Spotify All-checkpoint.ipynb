# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
# Loading the dataset
spotify = pd.read_csv('spotify_df.csv')

# %%
spotify1 =pd.read_csv('spotify1__df.csv')

# %%
spotify2=pd.read_csv('spotify_bdf.csv')

# %%
all_spotify=pd.concat([spotify, spotify1, spotify2], axis=0).reset_index()

# %%
all_spotify
# Out:
#       index  Unnamed: 0  danceability  energy  key  loudness  mode  \
# 0         0           0         0.522   0.817    0    -6.170     1
# 1         1           1         0.533   0.776    8    -7.092     1
# 2         2           2         0.692   0.651    9    -8.267     1
# 3         3           3         0.873   0.651    1    -4.179     1
# 4         4           4         0.682   0.605    8   -10.771     1
# ...     ...         ...           ...     ...  ...       ...   ...
# 6707   1619        1619         0.430   0.740   10    -7.072     1
# 6708   1620        1620         0.430   0.740   10    -7.072     1
# 6709   1621        1621         0.430   0.740   10    -7.072     1
# 6710   1622        1622         0.430   0.740   10    -7.072     1
# 6711   1623        1623         0.430   0.740   10    -7.072     1
#
#       speechiness  acousticness  instrumentalness  ...    tempo  \
# 0          0.0512        0.3290          0.000002  ...  151.106
# 1          0.0847        0.1510          0.000087  ...   90.061
# 2          0.0324        0.2920          0.002410  ...   97.923
# 3          0.0374        0.0251          0.000107  ...  115.002
# 4          0.0403        0.1850          0.003260  ...  125.960
# ...           ...           ...               ...  ...      ...
# 6707       0.0375        0.0212          0.001650  ...  137.978
# 6708       0.0375        0.0212          0.001650  ...  137.978
# 6709       0.0375        0.0212          0.001650  ...  137.978
# 6710       0.0375        0.0212          0.001650  ...  137.978
# 6711       0.0375        0.0212          0.001650  ...  137.978
#
#                 type                      id  \
# 0     audio_features  5SfM1f729pv1DdiEcyDiex
# 1     audio_features  7gyDV6Y7GmHqQS4KnzI5Zk
# 2     audio_features  0bRXwKfigvpKZUurwqAlEh
# 3     audio_features  2JHHXGSC6Ra3IJOBNLbhS6
# 4     audio_features  241RmK77gecJ1y7jOoQ5lu
# ...              ...                     ...
# 6707  audio_features  1yqMgZNrevsWMLWfO2PRp5
# 6708  audio_features  1yqMgZNrevsWMLWfO2PRp5
# 6709  audio_features  1yqMgZNrevsWMLWfO2PRp5
# 6710  audio_features  1yqMgZNrevsWMLWfO2PRp5
# 6711  audio_features  1yqMgZNrevsWMLWfO2PRp5
#
#                                        uri  \
# 0     spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                                    ...
# 6707  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6708  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6709  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6710  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6711  spotify:track:1yqMgZNrevsWMLWfO2PRp5
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 6707  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6708  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6709  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6710  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6711  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...      204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...      214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...      254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...      178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...      171360
# ...                                                 ...         ...
# 6707  https://api.spotify.com/v1/audio-analysis/1yqM...      285160
# 6708  https://api.spotify.com/v1/audio-analysis/1yqM...      285160
# 6709  https://api.spotify.com/v1/audio-analysis/1yqM...      285160
# 6710  https://api.spotify.com/v1/audio-analysis/1yqM...      285160
# 6711  https://api.spotify.com/v1/audio-analysis/1yqM...      285160
#
#      time_signature             artists  \
# 0                 4                Yola
# 1                 4  The War and Treaty
# 2                 4        Bill Withers
# 3                 4         Jon Batiste
# 4                 4        Natalie Cole
# ...             ...                 ...
# 6707              4          Becky Hill
# 6708              4       Sundara Karma
# 6709              4       Sundara Karma
# 6710              4       Sundara Karma
# 6711              4           Zeitgeist
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 6707           Better Off Without You (feat. Shift K3Y)
# 6708                                        Indigo Puff
# 6709                                           She Said
# 6710                                              Flame
# 6711                                     Come Over Here
#
# [6712 rows x 22 columns]

# %%
all_spotify.drop(columns =["Unnamed: 0", "index"], inplace=True)

# %%
all_spotify
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522   0.817    0    -6.170     1       0.0512        0.3290
# 1            0.533   0.776    8    -7.092     1       0.0847        0.1510
# 2            0.692   0.651    9    -8.267     1       0.0324        0.2920
# 3            0.873   0.651    1    -4.179     1       0.0374        0.0251
# 4            0.682   0.605    8   -10.771     1       0.0403        0.1850
# ...            ...     ...  ...       ...   ...          ...           ...
# 6707         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6708         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6709         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6710         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6711         0.430   0.740   10    -7.072     1       0.0375        0.0212
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000002    0.0807   0.5620  151.106  audio_features
# 1             0.000087    0.1300   0.6970   90.061  audio_features
# 2             0.002410    0.1050   0.7060   97.923  audio_features
# 3             0.000107    0.2130   0.8280  115.002  audio_features
# 4             0.003260    0.0469   0.9140  125.960  audio_features
# ...                ...       ...      ...      ...             ...
# 6707          0.001650    0.3300   0.0948  137.978  audio_features
# 6708          0.001650    0.3300   0.0948  137.978  audio_features
# 6709          0.001650    0.3300   0.0948  137.978  audio_features
# 6710          0.001650    0.3300   0.0948  137.978  audio_features
# 6711          0.001650    0.3300   0.0948  137.978  audio_features
#
#                           id                                   uri  \
# 0     5SfM1f729pv1DdiEcyDiex  spotify:track:5SfM1f729pv1DdiEcyDiex
# 1     7gyDV6Y7GmHqQS4KnzI5Zk  spotify:track:7gyDV6Y7GmHqQS4KnzI5Zk
# 2     0bRXwKfigvpKZUurwqAlEh  spotify:track:0bRXwKfigvpKZUurwqAlEh
# 3     2JHHXGSC6Ra3IJOBNLbhS6  spotify:track:2JHHXGSC6Ra3IJOBNLbhS6
# 4     241RmK77gecJ1y7jOoQ5lu  spotify:track:241RmK77gecJ1y7jOoQ5lu
# ...                      ...                                   ...
# 6707  1yqMgZNrevsWMLWfO2PRp5  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6708  1yqMgZNrevsWMLWfO2PRp5  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6709  1yqMgZNrevsWMLWfO2PRp5  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6710  1yqMgZNrevsWMLWfO2PRp5  spotify:track:1yqMgZNrevsWMLWfO2PRp5
# 6711  1yqMgZNrevsWMLWfO2PRp5  spotify:track:1yqMgZNrevsWMLWfO2PRp5
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5SfM1f729pv1...
# 1     https://api.spotify.com/v1/tracks/7gyDV6Y7GmHq...
# 2     https://api.spotify.com/v1/tracks/0bRXwKfigvpK...
# 3     https://api.spotify.com/v1/tracks/2JHHXGSC6Ra3...
# 4     https://api.spotify.com/v1/tracks/241RmK77gecJ...
# ...                                                 ...
# 6707  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6708  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6709  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6710  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
# 6711  https://api.spotify.com/v1/tracks/1yqMgZNrevsW...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5SfM...       204693
# 1     https://api.spotify.com/v1/audio-analysis/7gyD...       214187
# 2     https://api.spotify.com/v1/audio-analysis/0bRX...       254560
# 3     https://api.spotify.com/v1/audio-analysis/2JHH...       178290
# 4     https://api.spotify.com/v1/audio-analysis/241R...       171360
# ...                                                 ...          ...
# 6707  https://api.spotify.com/v1/audio-analysis/1yqM...       285160
# 6708  https://api.spotify.com/v1/audio-analysis/1yqM...       285160
# 6709  https://api.spotify.com/v1/audio-analysis/1yqM...       285160
# 6710  https://api.spotify.com/v1/audio-analysis/1yqM...       285160
# 6711  https://api.spotify.com/v1/audio-analysis/1yqM...       285160
#
#       time_signature             artists  \
# 0                  4                Yola
# 1                  4  The War and Treaty
# 2                  4        Bill Withers
# 3                  4         Jon Batiste
# 4                  4        Natalie Cole
# ...              ...                 ...
# 6707               4          Becky Hill
# 6708               4       Sundara Karma
# 6709               4       Sundara Karma
# 6710               4       Sundara Karma
# 6711               4           Zeitgeist
#
#                                              song_title
# 0                                 Diamond Studded Shoes
# 1                             Are You Ready to Love Me?
# 2                                            Lovely Day
# 3                                               FREEDOM
# 4     This Will Be (An Everlasting Love) - 2003 Rema...
# ...                                                 ...
# 6707           Better Off Without You (feat. Shift K3Y)
# 6708                                        Indigo Puff
# 6709                                           She Said
# 6710                                              Flame
# 6711                                     Come Over Here
#
# [6712 rows x 20 columns]

# %% [markdown]
# ## Scaling features

# %%
all_spotify.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean       0.632256     0.592998     5.082241    -8.672731     0.640644
# std        0.161920     0.226048     3.676953     5.255444     0.479848
# min        0.000000     0.002120     0.000000   -43.738000     0.000000
# 25%        0.543000     0.457000     1.000000    -9.744000     0.000000
# 50%        0.640000     0.625500     5.000000    -6.956000     1.000000
# 75%        0.757000     0.786250     8.000000    -5.479000     1.000000
# max        0.980000     1.000000    11.000000     0.175000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  6712.000000   6712.000000       6712.000000  6712.000000  6712.000000
# mean      0.093729      0.289713          0.119597     0.162981     0.518405
# std       0.092657      0.303277          0.278776     0.123491     0.231450
# min       0.000000      0.000018          0.000000     0.005350     0.000000
# 25%       0.038300      0.035800          0.000000     0.094800     0.329000
# 50%       0.054900      0.163000          0.000005     0.115000     0.524000
# 75%       0.100000      0.481000          0.004290     0.187000     0.703000
# max       0.916000      0.996000          0.976000     0.986000     0.979000
#
#              tempo   duration_ms  time_signature
# count  6712.000000  6.712000e+03     6712.000000
# mean    120.140743  2.102588e+05        3.941597
# std      28.946501  7.532201e+04        0.315758
# min       0.000000  5.061300e+04        0.000000
# 25%      97.597500  1.688082e+05        4.000000
# 50%     120.058500  2.026260e+05        4.000000
# 75%     140.188250  2.380000e+05        4.000000
# max     216.587000  1.252322e+06        5.000000

# %%
all_spotify_num = all_spotify._get_numeric_data()

# %%
X= all_spotify_num

# %%
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522   0.817    0    -6.170     1       0.0512        0.3290
# 1            0.533   0.776    8    -7.092     1       0.0847        0.1510
# 2            0.692   0.651    9    -8.267     1       0.0324        0.2920
# 3            0.873   0.651    1    -4.179     1       0.0374        0.0251
# 4            0.682   0.605    8   -10.771     1       0.0403        0.1850
# ...            ...     ...  ...       ...   ...          ...           ...
# 6707         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6708         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6709         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6710         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6711         0.430   0.740   10    -7.072     1       0.0375        0.0212
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000002    0.0807   0.5620  151.106       204693
# 1             0.000087    0.1300   0.6970   90.061       214187
# 2             0.002410    0.1050   0.7060   97.923       254560
# 3             0.000107    0.2130   0.8280  115.002       178290
# 4             0.003260    0.0469   0.9140  125.960       171360
# ...                ...       ...      ...      ...          ...
# 6707          0.001650    0.3300   0.0948  137.978       285160
# 6708          0.001650    0.3300   0.0948  137.978       285160
# 6709          0.001650    0.3300   0.0948  137.978       285160
# 6710          0.001650    0.3300   0.0948  137.978       285160
# 6711          0.001650    0.3300   0.0948  137.978       285160
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 6707               4
# 6708               4
# 6709               4
# 6710               4
# 6711               4
#
# [6712 rows x 13 columns]

# %% [markdown]
# The scale of "tempo" and "duration_ms" is much bigger than the scale of many other variable!
#
# K-Means is a distance based algorithm: we need to scale / normalize!:

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.522   0.817    0    -6.170     1       0.0512        0.3290
# 1         0.533   0.776    8    -7.092     1       0.0847        0.1510
# 2         0.692   0.651    9    -8.267     1       0.0324        0.2920
# 3         0.873   0.651    1    -4.179     1       0.0374        0.0251
# 4         0.682   0.605    8   -10.771     1       0.0403        0.1850
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000002    0.0807    0.562  151.106       204693               4
# 1          0.000087    0.1300    0.697   90.061       214187               4
# 2          0.002410    0.1050    0.706   97.923       254560               4
# 3          0.000107    0.2130    0.828  115.002       178290               4
# 4          0.003260    0.0469    0.914  125.960       171360               4
#    danceability    energy       key  loudness      mode  speechiness  \
# 0     -0.680982  0.991024 -1.382291  0.476252  0.748953    -0.459026
# 1     -0.613042  0.809633  0.793586  0.300802  0.748953    -0.097452
# 2      0.369001  0.256612  1.065570  0.077208  0.748953    -0.661940
# 3      1.486923  0.256612 -1.110307  0.855126  0.748953    -0.607974
# 4      0.307237  0.053100  0.793586 -0.399286  0.748953    -0.576673
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0      0.129552         -0.429035 -0.666346  0.188368  1.069821    -0.073899
# 1     -0.457414         -0.428730 -0.267095  0.771691 -1.039227     0.052156
# 2      0.007542         -0.420395 -0.469555  0.810579 -0.767602     0.588201
# 3     -0.872577         -0.428657  0.405071  1.337731 -0.177539    -0.424460
# 4     -0.345297         -0.417346 -0.940071  1.709329  0.201050    -0.516472
#
#    time_signature
# 0        0.184975
# 1        0.184975
# 2        0.184975
# 3        0.184975
# 4        0.184975

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  6.712000e+03  6.712000e+03  6.712000e+03  6.712000e+03  6.712000e+03
# mean  -3.381615e-16 -6.313649e-16 -2.219784e-16  3.736251e-16 -4.823714e-15
# std    1.000075e+00  1.000075e+00  1.000075e+00  1.000075e+00  1.000075e+00
# min   -3.905046e+00 -2.614143e+00 -1.382291e+00 -6.672678e+00 -1.335198e+00
# 25%   -5.512783e-01 -6.016770e-01 -1.110307e+00 -2.038551e-01 -1.335198e+00
# 50%    4.782940e-02  1.437954e-01 -2.236822e-02  3.266820e-01  7.489528e-01
# 75%    7.704645e-01  8.549805e-01  7.935855e-01  6.077448e-01  7.489528e-01
# max    2.147795e+00  1.800646e+00  1.609539e+00  1.683662e+00  7.489528e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  6.712000e+03  6.712000e+03      6.712000e+03  6.712000e+03
# mean  -2.079187e-16  3.261561e-15      6.049574e-15 -7.060966e-16
# std    1.000075e+00  1.000075e+00      1.000075e+00  1.000075e+00
# min   -1.011642e+00 -9.552856e-01     -4.290406e-01 -1.276559e+00
# 25%   -5.982596e-01 -8.372932e-01     -4.290406e-01 -5.521585e-01
# 50%   -4.190913e-01 -4.178433e-01     -4.290239e-01 -3.885711e-01
# 75%    6.768515e-02  6.307814e-01     -4.136508e-01  1.945126e-01
# max    8.874993e+00  2.329026e+00      3.072234e+00  6.665122e+00
#
#             valence         tempo   duration_ms  time_signature
# count  6.712000e+03  6.712000e+03  6.712000e+03    6.712000e+03
# mean  -6.808883e-16  1.227332e-17 -3.606902e-16   -1.637571e-15
# std    1.000075e+00  1.000075e+00  1.000075e+00    1.000075e+00
# min   -2.239984e+00 -4.150750e+00 -2.119668e+00   -1.248391e+01
# 25%   -8.184043e-01 -7.788479e-01 -5.503520e-01    1.849748e-01
# 50%    2.417348e-02 -2.841419e-03 -1.013429e-01    1.849748e-01
# 75%    7.976167e-01  6.926226e-01  3.683290e-01    1.849748e-01
# max    1.990188e+00  3.332128e+00  1.383581e+01    3.352197e+00

# %% [markdown]
# Now, all features will have the same weight.

# %% [markdown]
# ## Clustering the music with K-Means

# %%
kmeans = KMeans(n_clusters=11, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=11, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([10,  3,  3, ...,  3,  3,  3], dtype=int32)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 2])
    # show the plot
pyplot.show()

# %%
# Now we have our "model", let's get the clusters and how many observations has each cluster.

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     672
# 1     595
# 2     175
# 3     861
# 4     601
# 5     954
# 6     199
# 7     907
# 8     601
# 9     286
# 10    861
# dtype: int64

# %% [markdown]
# Now let's see to which group was assigned every song.

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.522   0.817    0    -6.170     1       0.0512        0.3290
# 1            0.533   0.776    8    -7.092     1       0.0847        0.1510
# 2            0.692   0.651    9    -8.267     1       0.0324        0.2920
# 3            0.873   0.651    1    -4.179     1       0.0374        0.0251
# 4            0.682   0.605    8   -10.771     1       0.0403        0.1850
# ...            ...     ...  ...       ...   ...          ...           ...
# 6707         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6708         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6709         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6710         0.430   0.740   10    -7.072     1       0.0375        0.0212
# 6711         0.430   0.740   10    -7.072     1       0.0375        0.0212
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000002    0.0807   0.5620  151.106       204693
# 1             0.000087    0.1300   0.6970   90.061       214187
# 2             0.002410    0.1050   0.7060   97.923       254560
# 3             0.000107    0.2130   0.8280  115.002       178290
# 4             0.003260    0.0469   0.9140  125.960       171360
# ...                ...       ...      ...      ...          ...
# 6707          0.001650    0.3300   0.0948  137.978       285160
# 6708          0.001650    0.3300   0.0948  137.978       285160
# 6709          0.001650    0.3300   0.0948  137.978       285160
# 6710          0.001650    0.3300   0.0948  137.978       285160
# 6711          0.001650    0.3300   0.0948  137.978       285160
#
#       time_signature  cluster
# 0                  4       10
# 1                  4        3
# 2                  4        3
# 3                  4        7
# 4                  4        7
# ...              ...      ...
# 6707               4        3
# 6708               4        3
# 6709               4        3
# 6710               4        3
# 6711               4        3
#
# [6712 rows x 14 columns]

# %%
X[X['cluster'] == 2].sample()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 216         0.441   0.176    7   -15.719     0       0.0376         0.989
#
#      instrumentalness  liveness  valence   tempo  duration_ms  time_signature  \
# 216             0.888     0.108    0.325  79.599       461000               4
#
#      cluster
# 216        2

# %% [markdown]
# ## Playing with the parameters

# %%
kmeans.inertia_
# Out:
# 42092.763176802415

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    #filename = "Model/kmeans_" + str(k) + ".pickle"
    #with open(filename, "wb") as f:
        #pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
##conda install -c districtdatalabs yellowbrick

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(3, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/cj/gbt4rs1d4tx3brkqknks4y5r0000gn/T/ipykernel_62199/1702674547.py in <module>
# ----> 1 from yellowbrick.cluster import SilhouetteVisualizer
#       2 model = KMeans(3, random_state=42)
#       3 visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
#       4 visualizer.fit(X_scaled_df)        # Fit the data to the visualizer
#       5 visualizer.show()        # Finalize and render the figure
#
# ModuleNotFoundError: No module named 'yellowbrick'
