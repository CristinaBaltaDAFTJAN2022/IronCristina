# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
vehicles_df= pd.read_csv("data/vehicles.csv") ## Your Code here
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %% [markdown]
# Câte observații are?
# Uită-te la toate coloanele: înțelegi ce înseamnă?
# Uită-te la datele brute: vezi ceva ciudat?
# Priviți tipurile de date: sunt cele așteptate pentru informațiile pe care le conține coloana?

# %%
print("Count before Removing Duplicates: ") # finding duplicate data
vehicles_df.count()
# Out:
# Count before Removing Duplicates:
# Make                       35952
# Model                      35952
# Year                       35952
# Engine Displacement        35952
# Cylinders                  35952
# Transmission               35952
# Drivetrain                 35952
# Vehicle Class              35952
# Fuel Type                  35952
# Fuel Barrels/Year          35952
# City MPG                   35952
# Highway MPG                35952
# Combined MPG               35952
# CO2 Emission Grams/Mile    35952
# Fuel Cost/Year             35952
# dtype: int64

# %%
print(vehicles_df.isnull().sum()) # Finding the missing or null values
# Out:
# Make                       0
# Model                      0
# Year                       0
# Engine Displacement        0
# Cylinders                  0
# Transmission               0
# Drivetrain                 0
# Vehicle Class              0
# Fuel Type                  0
# Fuel Barrels/Year          0
# City MPG                   0
# Highway MPG                0
# Combined MPG               0
# CO2 Emission Grams/Mile    0
# Fuel Cost/Year             0
# dtype: int64

# %%
vehicles_df.cnt = vehicles_df.count
print(vehicles_df.cnt)
## Your Code here
# Out:
# <bound method DataFrame.count of                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %%
vehicles_df.info() ## interogate the info data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
vehicles_Dutton=vehicles_df['Make'] ## Identify Colomn Make
vehicles_Dutton
# Out:
# 0              AM General
# 1              AM General
# 2              AM General
# 3              AM General
# 4        ASC Incorporated
#                ...
# 35947               smart
# 35948               smart
# 35949               smart
# 35950               smart
# 35951               smart
# Name: Make, Length: 35952, dtype: object

# %%
vehicles_df["Make"].str.contains("Dutton") ## we see where it is 'Dutton'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 35947    False
# 35948    False
# 35949    False
# 35950    False
# 35951    False
# Name: Make, Length: 35952, dtype: bool

# %%
vehicles_df["Make"][vehicles_df["Make"].str.contains("Dutton")] = "Dutton" ## we replace whith 'Dutton'
# Out:
# /var/folders/cj/gbt4rs1d4tx3brkqknks4y5r0000gn/T/ipykernel_46534/279847307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vehicles_df["Make"][vehicles_df["Make"].str.contains("Dutton")] = "Dutton" ## we replace whith 'Dutton'

# %%
vehicles_df["Make"][vehicles_df["Make"].str.contains("Dutton")]
# Out:
# 11012    Dutton
# 30164    Dutton
# 31754    Dutton
# Name: Make, dtype: object

# %%
vehicles_df.Make.value_counts() ## we identify all vehicle Make
# Out:
# Chevrolet                           3643
# Ford                                2946
# Dodge                               2360
# GMC                                 2347
# Toyota                              1836
# BMW                                 1677
# Mercedes-Benz                       1284
# Nissan                              1253
# Volkswagen                          1047
# Mitsubishi                           950
# Mazda                                915
# Audi                                 890
# Porsche                              862
# Honda                                836
# Jeep                                 829
# Pontiac                              784
# Subaru                               781
# Volvo                                717
# Hyundai                              662
# Chrysler                             641
# Buick                                537
# Mercury                              532
# Suzuki                               512
# ...

# %%
##vehicles_df["Make"][vehicles_df["Make"].str.contains(":")]

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %%
vehicles_df["CO2 Emission Grams/Mile"] = vehicles_df["CO2 Emission Grams/Mile"] / 1.60934
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use pandas.Series.str.startswith

# %%
transmission_df = vehicles_df.Transmission
print (transmission_df)
# Out:
# 0        Automatic 3-spd
# 1        Automatic 3-spd
# 2        Automatic 3-spd
# 3        Automatic 3-spd
# 4        Automatic 4-spd
#               ...
# 35947          Auto(AM5)
# 35948          Auto(AM5)
# 35949          Auto(AM5)
# 35950          Auto(AM6)
# 35951       Manual 5-spd
# Name: Transmission, Length: 35952, dtype: object

# %%
transmission_df.str.startswith('Auto')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 35947     True
# 35948     True
# 35949     True
# 35950     True
# 35951    False
# Name: Transmission, Length: 35952, dtype: bool

# %% [markdown]
# Convert MPG columns to km per liter (City MPG, Highway MPG, Combined MPG)

# %%
vehicles_df["City MPG"] = vehicles_df["City MPG"] * 1.60934 /3.78541

vehicles_df["Highway MPG"] = vehicles_df["Highway MPG"] * 1.60934 /3.78541

vehicles_df["Combined MPG"] = vehicles_df["Combined MPG"] * 1.60934 /3.78541

vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
vehicles_df = vehicles_df.astype({"City MPG":"int","Highway MPG":"int","Combined MPG":"int" })
print(vehicles_df.dtypes)
vehicles_df
# Out:
# Make                        object
# Model                       object
# Year                         int64
# Engine Displacement        float64
# Cylinders                  float64
# Transmission                object
# Drivetrain                  object
# Vehicle Class               object
# Fuel Type                   object
# Fuel Barrels/Year          float64
# City MPG                     int64
# Highway MPG                  int64
# Combined MPG                 int64
# CO2 Emission Grams/Mile    float64
# Fuel Cost/Year               int64
# dtype: object
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# ...

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
len(vehicles_df.Make.value_counts()) # the number von car makers 'Make'
# Out:
# 125

# %%
len(vehicles_df.Model.value_counts()) # how many models
# Out:
# 3608

# %%
vehicles_df.Make.value_counts() # Which car makers has the most cars in the dataset
# Out:
# Chevrolet                           3643
# Ford                                2946
# Dodge                               2360
# GMC                                 2347
# Toyota                              1836
# BMW                                 1677
# Mercedes-Benz                       1284
# Nissan                              1253
# Volkswagen                          1047
# Mitsubishi                           950
# Mazda                                915
# Audi                                 890
# Porsche                              862
# Honda                                836
# Jeep                                 829
# Pontiac                              784
# Subaru                               781
# Volvo                                717
# Hyundai                              662
# Chrysler                             641
# Buick                                537
# Mercury                              532
# Suzuki                               512
# ...

# %%
vehicles_df.Make.value_counts().max() # number max of cars made by makers
# Out:
# 3643

# %%
print(vehicles_df.Make.value_counts().head(1))
# Out:
# Chevrolet    3643
# Name: Make, dtype: int64

# %%
from collections import Counter

#def return_counter(data_frame, column_name, limit):
 # print(dict(Counter(data_frame[column_name]
  #.values).most_common(limit)))

def return_counter(vehicles_df, Make, limit):
    print(dict(Counter(vehicles_df[Make].value).most_comon(limit)))

# %% [markdown]
# When were these cars made?

# %%
list(vehicles_df.Year.value_counts())
# Out:
# [1581,
#  1264,
#  1228,
#  1211,
#  1198,
#  1188,
#  1184,
#  1183,
#  1168,
#  1156,
#  1139,
#  1127,
#  1126,
#  1124,
#  1122,
#  1119,
#  1113,
#  1108,
#  1107,
#  1099,
#  1077,
#  1068,
#  1034,
#  967,
#  961,
#  928,
#  902,
#  857,
#  828,
#  827,
#  791,
#  767,
#  755,
#  645]

# %% [markdown]
# How big is the engine of these cars?

# %%
vehicles_df.sort_values(by='Engine Displacement', ascending=False)

vehicles_df.sort_values(by='Engine Displacement', ascending=False).head(1)
# Out:
#         Make             Model  Year  Engine Displacement  Cylinders  \
# 10889  Dodge             Viper  2017                  8.4       10.0
# 10909  Dodge       Viper Coupe  2010                  8.4       10.0
# 30166    SRT             Viper  2014                  8.4       10.0
# 10911  Dodge         Viper SRT  2016                  8.4       10.0
# 30165    SRT             Viper  2013                  8.4       10.0
# ...      ...               ...   ...                  ...        ...
# 35939  smart  fortwo cabriolet  2017                  0.9        3.0
# 35938  smart  fortwo cabriolet  2017                  0.9        3.0
# 3071     BMW            i3 REX  2016                  0.6        2.0
# 3069     BMW            i3 REX  2014                  0.6        2.0
# 3070     BMW            i3 REX  2015                  0.6        2.0
#
#          Transmission        Drivetrain    Vehicle Class  \
# 10889    Manual 6-spd  Rear-Wheel Drive      Two Seaters
# ...

# %% [markdown]
# What's the frequency of different transmissions, drivetrains and fuel types?

# %%
print(vehicles_df.Transmission.value_counts()) #frequency of different transmissions
# Out:
# Automatic 4-spd                     10585
# Manual 5-spd                         7787
# Automatic (S6)                       2631
# Automatic 3-spd                      2597
# Manual 6-spd                         2423
# Automatic 5-spd                      2171
# Automatic 6-spd                      1432
# Manual 4-spd                         1306
# Automatic (S8)                        960
# Automatic (S5)                        822
# Automatic (variable gear ratios)      675
# Automatic 7-spd                       662
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        229
# Auto(AM7)                             157
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           74
# ...

# %%
print(vehicles_df.Drivetrain.value_counts()) # frequency of drivetrain
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %%
print(vehicles_df["Fuel Type"].value_counts()) # frequency of Fuel type
# Out:
# Regular                        23587
# Premium                         9921
# Gasoline or E85                 1195
# Diesel                           911
# Premium or E85                   121
# Midgrade                          74
# CNG                               60
# Premium and Electricity           20
# Gasoline or natural gas           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %% [markdown]
# What's the car that consumes the least/most fuel?

# %%
vehicles_df.sort_values(by='Fuel Barrels/Year', ascending=False) # consume moust fuel
# Out:
#               Make              Model  Year  Engine Displacement  Cylinders  \
# 20898  Lamborghini           Countach  1990                  5.2       12.0
# 20896  Lamborghini           Countach  1988                  5.2       12.0
# 20895  Lamborghini           Countach  1987                  5.2       12.0
# 20894  Lamborghini           Countach  1986                  5.2       12.0
# 20897  Lamborghini           Countach  1989                  5.2       12.0
# ...            ...                ...   ...                  ...        ...
# 17296        Honda          Civic CNG  2009                  1.8        4.0
# 17396        Honda  Civic Natural Gas  2013                  1.8        4.0
# 17398        Honda  Civic Natural Gas  2015                  1.8        4.0
# 17397        Honda  Civic Natural Gas  2014                  1.8        4.0
# 17395        Honda  Civic Natural Gas  2012                  1.8        4.0
#
# ...

# %%
vehicles_df.sort_values(by='Fuel Barrels/Year', ascending=False).head(1)
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20898  Lamborghini  Countach  1990                  5.2       12.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 20898  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20898          47.087143         2            4             2
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 20898               788.877073            5800

# %%
vehicles_df.sort_values(by='Fuel Barrels/Year', ascending=True) # consume least fuel
# Out:
#               Make              Model  Year  Engine Displacement  Cylinders  \
# 17396        Honda  Civic Natural Gas  2013                  1.8        4.0
# 17395        Honda  Civic Natural Gas  2012                  1.8        4.0
# 17397        Honda  Civic Natural Gas  2014                  1.8        4.0
# 17398        Honda  Civic Natural Gas  2015                  1.8        4.0
# 17288        Honda          Civic CNG  2001                  1.7        4.0
# ...            ...                ...   ...                  ...        ...
# 20897  Lamborghini           Countach  1989                  5.2       12.0
# 20894  Lamborghini           Countach  1986                  5.2       12.0
# 20896  Lamborghini           Countach  1988                  5.2       12.0
# 20898  Lamborghini           Countach  1990                  5.2       12.0
# 20895  Lamborghini           Countach  1987                  5.2       12.0
#
# ...

# %%
vehicles_df.sort_values(by='Fuel Barrels/Year', ascending=True).head(1)
# Out:
#         Make              Model  Year  Engine Displacement  Cylinders  \
# 17396  Honda  Civic Natural Gas  2013                  1.8        4.0
#
#           Transmission         Drivetrain Vehicle Class Fuel Type  \
# 17396  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 17396               0.06        11           16            13
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 17396               135.459257            1000

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
vehicles_df.sort_values(by='CO2 Emission Grams/Mile', ascending=False)
#vehicles_df.CO2_Emission.value_counts() ## your Code here
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# ...            ...       ...   ...                  ...        ...
# 7917     Chevrolet      Volt  2017                  1.5        4.0
# 7916     Chevrolet      Volt  2016                  1.5        4.0
# 3070           BMW    i3 REX  2015                  0.6        2.0
# 3069           BMW    i3 REX  2014                  0.6        2.0
# 3071           BMW    i3 REX  2016                  0.6        2.0
#
#                            Transmission         Drivetrain    Vehicle Class  \
# 20897                      Manual 5-spd   Rear-Wheel Drive      Two Seaters
# ...

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
    
transmission_df = print(vehicles_df[('Transmission')])
if 'Transmission'= 'auto' count(transmission_df)
#len(vehicles_df['Transmission':'Auto'])

#fuel_df=print(vehicles_df[('Fuel Type')])

#vehicles_df.count('Transmission'=='Auto')
#def Average(lst):
 #   return sum(lst) / len(lst)
#lst = [15, 9, 55, 41, 35, 20, 62, 49]
#average = Average(lst)
#print("Average of the list =", round(average, 2)
#auto = vehicle_df.[('Transmission', 'auto')] # cars with automatic transmission

#len(vehicles_df.Transmission.value_counts()) ## Your Code is here
# Out:
#   File "/var/folders/cj/gbt4rs1d4tx3brkqknks4y5r0000gn/T/ipykernel_46534/2452430618.py", line 2
#     if 'Transmission'= 'auto' count(transmission_df)
#                      ^
# SyntaxError: invalid syntax
